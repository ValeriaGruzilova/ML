# %% [markdown]
# # Логистическая регрессия
#
# 0 - отрицательный класс
# 1 - положительный класс
#
# ![image.png](attachment:image.png)
# Вероятность того, что вектор х принадлежит к классу 1:
# ![image-2.png](attachment:image-2.png)
#
# Разделяющая поверхность (гиперплоскость разделения на классы) - граница решений.
# ![image-3.png](attachment:image-3.png)
#
#
# Функция стоимости и потерь:
# ![image-8.png](attachment:image-8.png)
# (бинарная кросс-энтропия)

# %% [markdown]
# **Многоклассовая классификация**
#
# "Один против всех":
# ![image.png](attachment:image.png)
#
#
# **Регуляризация L2 (Риджа)** - метод борьбы с переобучением (уменьшение весов).
# Большое лямбда => недообучение (дисперсия => 0)
# ![image-2.png](attachment:image-2.png)
